# %% [markdown]
# 1. Load the dataset

# %%
import pandas as pd

df = pd.read_csv(r"C:\xampp\htdocs\HousePrediction\data\external\VN_housing_dataset.csv")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82497 entries, 0 to 82496
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       82496 non-null  float64
#  1   Ngày             82496 non-null  object
#  2   Địa chỉ          82449 non-null  object
#  3   Quận             82495 non-null  object
#  4   Huyện            82449 non-null  object
#  5   Loại hình nhà ở  82465 non-null  object
#  6   Giấy tờ pháp lý  53610 non-null  object
#  7   Số tầng          36399 non-null  object
#  8   Số phòng ngủ     82458 non-null  object
#  9   Diện tích        82495 non-null  object
#  10  Dài              19827 non-null  object
#  11  Rộng             35445 non-null  object
#  12  Giá/m2           82484 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 8.2+ MB

# %% [markdown]
# 2. Check for Missing Values

# %%
missing = df.isnull().sum()
missing[missing > 0]
# Out:
# Unnamed: 0             1
# Ngày                   1
# Địa chỉ               48
# Quận                   2
# Huyện                 48
# Loại hình nhà ở       32
# Giấy tờ pháp lý    28887
# Số tầng            46098
# Số phòng ngủ          39
# Diện tích              2
# Dài                62670
# Rộng               47052
# Giá/m2                13
# dtype: int64

# %% [markdown]
# 3. Check for Duplicates

# %%
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# 5. Check for Bias Risks

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df['Giấy tờ pháp lý'].value_counts(dropna=False).plot.bar()
#       2 plt.show()
#
# File c:\xampp\htdocs\HousePrediction\.venv\Lib\site-packages\pandas\plotting\_core.py:1192, in PlotAccessor.bar(self, x, y, **kwargs)
#    1102 @Appender(
#    1103     """
#    1104     See Also
#    (...)   1181     self, x: Hashable | None = None, y: Hashable | None = None, **kwargs
#    1182 ) -> PlotAccessor:
#    1183     """
#    1184     Vertical bar plot.
#    1185
#    (...)   1190     other axis represents a measured value.
#    1191     """
# -> 1192     return self(kind="bar", x=x, y=y, **kwargs)
#
# File c:\xampp\htdocs\HousePrediction\.venv\Lib\site-packages\pandas\plotting\_core.py:947, in PlotAccessor.__call__(self, *args, **kwargs)
#     946 def __call__(self, *args, **kwargs):
# --> 947     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     949     x, y, kind, kwargs = self._get_call_args(
#     950         plot_backend.__name__, self._parent, args, kwargs
#     951     )
#     953     kind = self._kind_aliases.get(kind, kind)
#
# File c:\xampp\htdocs\HousePrediction\.venv\Lib\site-packages\pandas\plotting\_core.py:1944, in _get_plot_backend(backend)
#    1941 if backend_str in _backends:
#    1942     return _backends[backend_str]
# -> 1944 module = _load_backend(backend_str)
#    1945 _backends[backend_str] = module
#    1946 return module
#
# File c:\xampp\htdocs\HousePrediction\.venv\Lib\site-packages\pandas\plotting\_core.py:1874, in _load_backend(backend)
#    1872         module = importlib.import_module("pandas.plotting._matplotlib")
#    1873     except ImportError:
# -> 1874         raise ImportError(
#    1875             "matplotlib is required for plotting when the "
#    1876             'default backend "matplotlib" is selected.'
#    1877         ) from None
#    1878     return module
#    1880 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
